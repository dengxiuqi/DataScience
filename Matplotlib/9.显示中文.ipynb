# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
# %matplotlib inline

# %% [markdown]
# #### 设置字体

# %%
myfont = fm.FontProperties(fname="font/SimHei.ttf")

# %%
x = [1,2,3]
y = [1,2,3]
plt.plot(x, y)
plt.title("图", fontproperties=myfont, fontsize=20)
# Out:
# Text(0.5,1,'图')
