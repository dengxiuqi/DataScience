# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("data/london2018.csv")
df
# Out:
#     Year  Month  Tmax  Tmin  Rain    Sun
# 0   2018      1   9.7   3.8  58.0   46.5
# 1   2018      2   6.7   0.6  29.0   92.0
# 2   2018      3   9.8   3.0  81.2   70.3
# 3   2018      4  15.5   7.9  65.2  113.4
# 4   2018      5  20.8   9.8  58.4  248.3
# 5   2018      6  24.2  13.1   0.4  234.5
# 6   2018      7  28.3  16.4  14.8  272.5
# 7   2018      8  24.5  14.5  48.2  182.1
# 8   2018      9  20.9  11.0  29.4  195.0
# 9   2018     10  16.5   8.5  61.0  137.0
# 10  2018     11  12.2   5.8  73.8   72.9
# 11  2018     12  10.7   5.2  60.6   40.3

# %% [markdown]
# #### df.plot(x, y, kind, figsize, title, grid, legend, style)
#
#     x 只有dataframe对象时，x可用。横坐标
#     y 同上，纵坐标变量
#     kind 可视化图的种类，如line,hist, bar, barh, pie, kde, scatter
#     figsize 画布尺寸
#     title 标题
#     grid 是否显示格子线条
#     legend 是否显示图例
#     style 图的风格

# %% [markdown]
# #### 10.1 折线图
# * plot默认就是折线图
# * 横坐标轴参数x传入的是df中的列名Month
# * 纵坐标轴参数y传入的是df中的列名Tmax

# %%
df.plot(x="Month", y="Tmax")

# %% [markdown]
# * grid绘制格线

# %%
df.plot(x="Month", y="Tmax", grid=True)

# %% [markdown]
# * 多个y值

# %%
df.plot(x="Month", y=["Tmax", "Tmin"])

# %% [markdown]
# #### 10.2 条形图

# %% [markdown]
# * 用plot画

# %%
df.plot(x="Month", y="Rain", kind="bar")

# %% [markdown]
# * 用bar画

# %%
df.plot.bar(x="Month", y="Rain")

# %% [markdown]
# * 水平条形图

# %%
df.plot(x="Month", y="Rain", kind="barh")

# %% [markdown]
# * 多变量条形图

# %%
df.plot(x="Month", y=["Tmax", "Tmin"], kind="bar")

# %% [markdown]
# #### 10.3 散点图

# %%
df.plot(x="Month", y="Sun", kind="scatter")

# %%
df.plot.scatter(x="Month", y="Rain", color="orange")

# %% [markdown]
# #### 10.4 饼图

# %%
df.index = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
df.plot(y="Sun", 
        kind="pie", 
        figsize=(6, 6), 
        legend=False)

# %% [markdown]
# #### 10.5 直方图

# %%
df = pd.read_csv("data/titanic.csv")
df.head()
df.plot(y="Age", kind="hist")

# %% [markdown]
# 坐标的刻度可以通过bins设置

# %%
df.plot(y="Age", kind="hist", bins=range(0, 100, 5))
